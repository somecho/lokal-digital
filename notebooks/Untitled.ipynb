# %%
import pandas as pd
import os

# %%
data = pd.read_csv('data.csv',delim_whitespace=True)

# %%
data.head()
# Out:
#       mfcc1     mfcc2     mfcc3     mfcc4     mfcc5     mfcc6     mfcc7  \
# 0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.444715 -0.287709 -0.264263  0.002701 -0.122007 -0.268071 -0.070474
# 2  0.397549 -0.414824 -0.350074  0.061697  0.028563 -0.187793 -0.051858
# 3  0.352403 -0.510416 -0.344062  0.276978  0.252956 -0.272204 -0.384704
# 4  0.419314 -0.473640 -0.532359  0.057549  0.362671  0.068878 -0.351105
#
#       mfcc8     mfcc9    mfcc10  ...    mfcc37  num_onset      RMS  \
# 0  0.000000  0.000000  0.000000  ...  0.000000      0.001   0.0000
# 1  0.084014 -0.006422  0.047916  ...  0.006513      5.001  66.0383
# 2  0.240900  0.157228 -0.190137  ...  0.005316     10.001  76.2283
# 3  0.076323  0.338335  0.007893  ...  0.019524     12.001  80.7904
# 4 -0.386196 -0.021932  0.319679  ...  0.052105     14.001  84.5981
#
#    spec_centroid  spec_irregularity  spec_flux  spec_sped  spec_bright  \
# ...

# %%
try:
    if os.path.isfile('data.csv') is False:
        os.rename('data.txt','data.csv')
        print('data.txt converted to data.csv')
    else:
        print('data.csv exists. Moving on.')
except FileNotFoundError:
    print('File missing: The file data.txt/csv is not found.')
    print('Make sure data.txt/csv is in the same directory as this script')
# Out:
# data.csv exists. Moving on.

# %%
os.path.isfile('data.txt')
# Out:
# False
